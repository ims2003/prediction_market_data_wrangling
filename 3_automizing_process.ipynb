# %% [markdown]
# # Automization
#
# ## To Do
# - create loop to run steps 1 and 2 for each market
# - get list of all markets im studying
# - run loop and store outputs
# - present

# %% [markdown]
# # Next / Analysis Steps
# - I would use the current data that identifies whales along with a predefined (maybe variable) time frame to see how the price changes after different periods of time since a whale action (buy or sell)
